# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://asus:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Following Count:{ith_tweet[1]}")
    print(f"Follower Count:{ith_tweet[2]}")
    print(f"Total Tweets:{ith_tweet[3]}")
    print(f"Retweet Count:{ith_tweet[4]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','following','followers', 'totaltweets', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,following,followers,totaltweets, retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'PApQojAQOSd8iWdMdWeumD5i2'
consumer_secret = 'lUEA33FLEUK1hO52LlLnRbFulopaDYYLes5EDqnImO5XmyPqLg'
access_key = '1425317741997694976-IkA7s2zdUdQp1XdiO2YZaWDaUTSk3D'
access_secret = 'jdb2xaTL50gfiyIGx6aNMwihLe0ff0T4peX0ectErrYEy'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-20"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:aiimannnnnn
# Following Count:340
# Follower Count:183
# Total Tweets:1836
# Retweet Count:2237
#
# Tweet 2:
# Username:alecwriter120
# Following Count:5001
# Follower Count:2637
# Total Tweets:90264
# Retweet Count:0
#
# Tweet 3:
# Username:RealAlexCorral
# Following Count:1535
# Follower Count:14849
# Total Tweets:2443
# Retweet Count:0
#
# Tweet 4:
# Username:AKFavoriteDish
# Following Count:262
# Follower Count:25
# Total Tweets:680
# Retweet Count:287
#
# Tweet 5:
# Username:alecwriter120
# Following Count:5001
# Follower Count:2637
# Total Tweets:90264
# Retweet Count:99
#
# Tweet 6:
# Username:burgheartodd
# Following Count:22
# Follower Count:10
# Total Tweets:40
# Retweet Count:1
#
# Tweet 7:
# Username:_isaiahjdavis
# Following Count:39
# Follower Count:1
# Total Tweets:30
# Retweet Count:0
#
# Tweet 8:
# Username:HolleeQuinn92
# Following Count:191
# Follower Count:173
# Total Tweets:5276
# Retweet Count:0
#
# Tweet 9:
# Username:9algola
# Following Count:123
# Follower Count:831
# Total Tweets:11621
# Retweet Count:2237
#
# Tweet 10:
# Username:Don_kaiju
# Following Count:303
# Follower Count:215
# Total Tweets:5326
# Retweet Count:0
#
# Tweet 11:
# Username:rey54360
# Following Count:79
# Follower Count:25
# Total Tweets:4442
# Retweet Count:567
#
# Tweet 12:
# Username:The_PlugSeeker
# Following Count:1257
# Follower Count:5298
# Total Tweets:188723
# Retweet Count:567
#
# Tweet 13:
# Username:The_PlugSeeker
# Following Count:1257
# Follower Count:5298
# Total Tweets:188723
# Retweet Count:17
#
# Tweet 14:
# Username:REDDECORATE
# Following Count:207
# Follower Count:235
# Total Tweets:6216
# Retweet Count:0
#
# Tweet 15:
# Username:weed10_weed
# Following Count:475
# Follower Count:124
# Total Tweets:3091
# Retweet Count:1
#
# Tweet 16:
# Username:SurvivalZippy
# Following Count:534
# Follower Count:246
# Total Tweets:5857
# Retweet Count:32
#
# Tweet 17:
# Username:REDDECORATE
# Following Count:207
# Follower Count:235
# Total Tweets:6216
# Retweet Count:0
#
# Tweet 18:
# Username:Tedestrela
# Following Count:5034
# Follower Count:4789
# Total Tweets:76804
# Retweet Count:32
#
# Tweet 19:
# Username:1914to1945
# Following Count:151
# Follower Count:5
# Total Tweets:341
# Retweet Count:567
#
# Tweet 20:
# Username:robinsonmarga20
# Following Count:345
# Follower Count:543
# Total Tweets:46338
# Retweet Count:32
#
# Tweet 21:
# Username:iXerrorXi
# Following Count:6
# Follower Count:4
# Total Tweets:1059
# Retweet Count:0
#
# Tweet 22:
# Username:Abdurflash69
# Following Count:86
# Follower Count:62
# Total Tweets:1462
# Retweet Count:19
#
# Tweet 23:
# Username:AceJon
# Following Count:355
# Follower Count:373
# Total Tweets:16703
# Retweet Count:0
#
# Tweet 24:
# Username:HondtWerner
# Following Count:39
# Follower Count:81
# Total Tweets:1820
# Retweet Count:27
#
# Tweet 25:
# Username:apcchief_phukan
# Following Count:4992
# Follower Count:1121
# Total Tweets:3736
# Retweet Count:5
#
# Tweet 26:
# Username:ammar_hlm
# Following Count:335
# Follower Count:235
# Total Tweets:25929
# Retweet Count:2237
#
# Tweet 27:
# Username:SalomonOli
# Following Count:2664
# Follower Count:3298
# Total Tweets:89499
# Retweet Count:10
#
# Tweet 28:
# Username:ravihanskahar
# Following Count:104
# Follower Count:15
# Total Tweets:237
# Retweet Count:567
#
# Tweet 29:
# Username:lsrlinda
# Following Count:4994
# Follower Count:4418
# Total Tweets:338813
# Retweet Count:32
#
# Tweet 30:
# Username:Marcus08090087
# Following Count:111
# Follower Count:217
# Total Tweets:43305
# Retweet Count:27
#
# Tweet 31:
# Username:Marko54789473
# Following Count:145
# Follower Count:43
# Total Tweets:458
# Retweet Count:567
#
# Tweet 32:
# Username:kenkou2heiwa2
# Following Count:980
# Follower Count:1019
# Total Tweets:69969
# Retweet Count:238
#
# Tweet 33:
# Username:Fr_ever_unknown
# Following Count:42
# Follower Count:41
# Total Tweets:107
# Retweet Count:1
#
# Tweet 34:
# Username:nymphoteric
# Following Count:322
# Follower Count:169
# Total Tweets:6738
# Retweet Count:0
#
# Tweet 35:
# Username:47_hull
# Following Count:164
# Follower Count:194
# Total Tweets:4417
# Retweet Count:32
#
# Tweet 36:
# Username:gaurav13194
# Following Count:4864
# Follower Count:143
# Total Tweets:23545
# Retweet Count:66
#
# Tweet 37:
# Username:Lkseng3
# Following Count:466
# Follower Count:445
# Total Tweets:31473
# Retweet Count:14
#
# Tweet 38:
# Username:AntifaCatra
# Following Count:3405
# Follower Count:1976
# Total Tweets:174599
# Retweet Count:99
#
# Tweet 39:
# Username:kg5725kg
# Following Count:369
# Follower Count:291
# Total Tweets:2510
# Retweet Count:567
#
# Tweet 40:
# Username:SteveinHawaii6
# Following Count:180
# Follower Count:16
# Total Tweets:115
# Retweet Count:567
#
# Tweet 41:
# Username:diasporadicals
# Following Count:708
# Follower Count:394
# Total Tweets:13058
# Retweet Count:0
#
# Tweet 42:
# Username:defiunicorn
# Following Count:814
# Follower Count:821
# Total Tweets:5976
# Retweet Count:13
#
# Tweet 43:
# Username:lil57752
# Following Count:865
# Follower Count:139
# Total Tweets:10573
# Retweet Count:2237
#
# Tweet 44:
# Username:_ufnatasha
# Following Count:217
# Follower Count:233
# Total Tweets:45508
# Retweet Count:2237
#
# Tweet 45:
# Username:cerufiffy
# Following Count:3936
# Follower Count:1032
# Total Tweets:12451
# Retweet Count:287
#
# Tweet 46:
# Username:Sifonet
# Following Count:91
# Follower Count:200
# Total Tweets:28045
# Retweet Count:567
#
# Tweet 47:
# Username:TheWheelYard
# Following Count:682
# Follower Count:763
# Total Tweets:7125
# Retweet Count:0
#
# Tweet 48:
# Username:pavitraputul
# Following Count:50
# Follower Count:3413
# Total Tweets:13556
# Retweet Count:0
#
# Tweet 49:
# Username:Iamfitinvestor
# Following Count:583
# Follower Count:267
# Total Tweets:450
# Retweet Count:1
#
# Tweet 50:
# Username:Lyaniva_jay
# Following Count:325
# Follower Count:48
# Total Tweets:997
# Retweet Count:5
#
# Tweet 51:
# Username:its_tshiamo
# Following Count:58
# Follower Count:80
# Total Tweets:1103
# Retweet Count:66
#
# Tweet 52:
# Username:AndersStromgren
# Following Count:454
# Follower Count:350
# Total Tweets:105005
# Retweet Count:1
#
# Tweet 53:
# Username:LeedsNews3
# Following Count:0
# Follower Count:2
# Total Tweets:1541
# Retweet Count:0
#
# Tweet 54:
# Username:LuisVarandas4
# Following Count:28
# Follower Count:11
# Total Tweets:669
# Retweet Count:2960
#
# Tweet 55:
# Username:RussC_
# Following Count:262
# Follower Count:267
# Total Tweets:13690
# Retweet Count:0
#
# Tweet 56:
# Username:LiliMuller5
# Following Count:454
# Follower Count:200
# Total Tweets:3132
# Retweet Count:0
#
# Tweet 57:
# Username:peanutburer
# Following Count:87
# Follower Count:9
# Total Tweets:337
# Retweet Count:2237
#
# Tweet 58:
# Username:stephfinebot
# Following Count:0
# Follower Count:9
# Total Tweets:87499
# Retweet Count:0
#
# Tweet 59:
# Username:PamelaGarcialse
# Following Count:73
# Follower Count:35
# Total Tweets:445
# Retweet Count:1
#
# Tweet 60:
# Username:Lyaniva_jay
# Following Count:325
# Follower Count:48
# Total Tweets:997
# Retweet Count:43
#
# Tweet 61:
# Username:wisteriawitch
# Following Count:1607
# Follower Count:2452
# Total Tweets:333873
# Retweet Count:32
#
# Tweet 62:
# Username:loliieeee
# Following Count:63
# Follower Count:3
# Total Tweets:5
# Retweet Count:567
#
# Tweet 63:
# Username:_TopTechNews
# Following Count:0
# Follower Count:140
# Total Tweets:24336
# Retweet Count:0
#
# Tweet 64:
# Username:013Enterprises
# Following Count:252
# Follower Count:94
# Total Tweets:6882
# Retweet Count:0
#
# Tweet 65:
# Username:BrunoAy
# Following Count:45
# Follower Count:7
# Total Tweets:12
# Retweet Count:0
#
# Tweet 66:
# Username:TheWhiteResorts
# Following Count:299
# Follower Count:22
# Total Tweets:765
# Retweet Count:567
#
# Tweet 67:
# Username:itsJoeLahhhhh
# Following Count:170
# Follower Count:63
# Total Tweets:1657
# Retweet Count:0
#
# Tweet 68:
# Username:013Enterprises
# Following Count:252
# Follower Count:94
# Total Tweets:6882
# Retweet Count:0
#
# Tweet 69:
# Username:9mm_trilla
# Following Count:469
# Follower Count:80
# Total Tweets:405
# Retweet Count:0
#
# Tweet 70:
# Username:foolsbookie
# Following Count:139
# Follower Count:1081
# Total Tweets:13709
# Retweet Count:0
#
# Tweet 71:
# Username:Mr_Retro7
# Following Count:7
# Follower Count:17
# Total Tweets:483
# Retweet Count:0
#
# Tweet 72:
# Username:tasyaharley
# Following Count:460
# Follower Count:84
# Total Tweets:894
# Retweet Count:0
#
# Tweet 73:
# Username:Hv4YxOqZUUdW3bp
# Following Count:3
# Follower Count:0
# Total Tweets:1
# Retweet Count:567
#
# Tweet 74:
# Username:StephanHaas6
# Following Count:12
# Follower Count:2
# Total Tweets:83
# Retweet Count:567
#
# Tweet 75:
# Username:ehisidegb
# Following Count:1963
# Follower Count:94
# Total Tweets:3912
# Retweet Count:0
#
# Tweet 76:
# Username:imansabrina_
# Following Count:360
# Follower Count:577
# Total Tweets:41204
# Retweet Count:2237
#
# Tweet 77:
# Username:NaaZainal
# Following Count:384
# Follower Count:862
# Total Tweets:15049
# Retweet Count:2237
#
# Tweet 78:
# Username:Kart759
# Following Count:92
# Follower Count:19
# Total Tweets:15
# Retweet Count:567
#
# Tweet 79:
# Username:mrjbeeds
# Following Count:1777
# Follower Count:283
# Total Tweets:6831
# Retweet Count:567
#
# Tweet 80:
# Username:gummyphos
# Following Count:595
# Follower Count:192
# Total Tweets:24933
# Retweet Count:287
#
# Tweet 81:
# Username:JoeMcG1888
# Following Count:57
# Follower Count:19
# Total Tweets:119
# Retweet Count:567
#
# Tweet 82:
# Username:DanaEn803
# Following Count:2089
# Follower Count:645
# Total Tweets:14479
# Retweet Count:567
#
# Tweet 83:
# Username:cassieasper
# Following Count:1602
# Follower Count:1090
# Total Tweets:8588
# Retweet Count:841
#
# Tweet 84:
# Username:n_ramnath
# Following Count:194
# Follower Count:98
# Total Tweets:7798
# Retweet Count:66
#
# Tweet 85:
# Username:euronews
# Following Count:1109
# Follower Count:470675
# Total Tweets:151586
# Retweet Count:2
#
# Tweet 86:
# Username:RUS__ya
# Following Count:311
# Follower Count:153
# Total Tweets:2384
# Retweet Count:567
#
# Tweet 87:
# Username:euronewsnext
# Following Count:112
# Follower Count:6247
# Total Tweets:4698
# Retweet Count:2
#
# Tweet 88:
# Username:Sidthesexist3
# Following Count:80
# Follower Count:23
# Total Tweets:1843
# Retweet Count:32
#
# Tweet 89:
# Username:cassieasper
# Following Count:1602
# Follower Count:1090
# Total Tweets:8588
# Retweet Count:2960
#
# Tweet 90:
# Username:SocialBizBrand
# Following Count:4535
# Follower Count:5741
# Total Tweets:132532
# Retweet Count:0
#
# Tweet 91:
# Username:jayrajmane
# Following Count:2379
# Follower Count:248
# Total Tweets:8210
# Retweet Count:66
#
# Tweet 92:
# Username:Gate_Capital_Uk
# Following Count:441
# Follower Count:41095
# Total Tweets:9059
# Retweet Count:567
#
# Tweet 93:
# Username:ElonAnnounces
# Following Count:1
# Follower Count:111
# Total Tweets:33794
# Retweet Count:0
#
# Tweet 94:
# Username:Massage98259908
# Following Count:25
# Follower Count:0
# Total Tweets:7
# Retweet Count:567
#
# Tweet 95:
# Username:sueatkilmeedy
# Following Count:502
# Follower Count:1766
# Total Tweets:163807
# Retweet Count:32
#
# Tweet 96:
# Username:IrwinGoyetteIV
# Following Count:896
# Follower Count:251
# Total Tweets:1842
# Retweet Count:0
#
# Tweet 97:
# Username:sutty56
# Following Count:612
# Follower Count:609
# Total Tweets:31828
# Retweet Count:32
#
# Tweet 98:
# Username:IDoIdeasAndMore
# Following Count:332
# Follower Count:2640
# Total Tweets:454
# Retweet Count:43
#
# Tweet 99:
# Username:phatkaps108
# Following Count:73
# Follower Count:6
# Total Tweets:46
# Retweet Count:676
#
# Tweet 100:
# Username:DownsBotany
# Following Count:5
# Follower Count:0
# Total Tweets:4
# Retweet Count:567
