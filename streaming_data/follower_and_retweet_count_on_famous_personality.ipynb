# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://asus:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Follower Count:{ith_tweet[1]}")
    print(f"Retweet Count:{ith_tweet[2]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','followers', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        followers = tweet.user.followers_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,followers,retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'PApQojAQOSd8iWdMdWeumD5i2'
consumer_secret = 'lUEA33FLEUK1hO52LlLnRbFulopaDYYLes5EDqnImO5XmyPqLg'
access_key = '1425317741997694976-IkA7s2zdUdQp1XdiO2YZaWDaUTSk3D'
access_secret = 'jdb2xaTL50gfiyIGx6aNMwihLe0ff0T4peX0ectErrYEy'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "joebiden"
date_since = "2021-06-05"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:MAQuested
# Follower Count:163
# Retweet Count:0
#
# Tweet 2:
# Username:tweetwithvimal
# Follower Count:204
# Retweet Count:0
#
# Tweet 3:
# Username:manapisca
# Follower Count:102
# Retweet Count:593
#
# Tweet 4:
# Username:gellio_sf
# Follower Count:517
# Retweet Count:1
#
# Tweet 5:
# Username:GotBrexitDone1
# Follower Count:11668
# Retweet Count:0
#
# Tweet 6:
# Username:atmic_nidhi
# Follower Count:191
# Retweet Count:0
#
# Tweet 7:
# Username:FaragSaber6
# Follower Count:44
# Retweet Count:0
#
# Tweet 8:
# Username:gellio_sf
# Follower Count:517
# Retweet Count:0
#
# Tweet 9:
# Username:509Tiernan
# Follower Count:66
# Retweet Count:16
#
# Tweet 10:
# Username:brooklynux
# Follower Count:303
# Retweet Count:0
#
# Tweet 11:
# Username:mumbai_mitra
# Follower Count:77
# Retweet Count:0
#
# Tweet 12:
# Username:FaragSaber6
# Follower Count:44
# Retweet Count:0
#
# Tweet 13:
# Username:Yelsi37
# Follower Count:6
# Retweet Count:0
#
# Tweet 14:
# Username:Dailyvruttmitra
# Follower Count:297
# Retweet Count:0
#
# Tweet 15:
# Username:DrAkbarKhan15
# Follower Count:29
# Retweet Count:121
#
# Tweet 16:
# Username:Jim22629577
# Follower Count:23
# Retweet Count:434
#
# Tweet 17:
# Username:lousybug
# Follower Count:213
# Retweet Count:0
#
# Tweet 18:
# Username:MAQuested
# Follower Count:163
# Retweet Count:0
#
# Tweet 19:
# Username:JackDon01066055
# Follower Count:175
# Retweet Count:3
#
# Tweet 20:
# Username:blairha35179794
# Follower Count:0
# Retweet Count:0
#
# Tweet 21:
# Username:captaintwitts
# Follower Count:195
# Retweet Count:0
#
# Tweet 22:
# Username:Kizimabwindi
# Follower Count:3
# Retweet Count:0
#
# Tweet 23:
# Username:KDeedwaniya
# Follower Count:107
# Retweet Count:0
#
# Tweet 24:
# Username:kolkygn
# Follower Count:1978
# Retweet Count:2392
#
# Tweet 25:
# Username:KaiserQueef
# Follower Count:237
# Retweet Count:0
#
# Tweet 26:
# Username:MAQuested
# Follower Count:163
# Retweet Count:0
#
# Tweet 27:
# Username:Yelsi37
# Follower Count:6
# Retweet Count:0
#
# Tweet 28:
# Username:FaragSaber6
# Follower Count:44
# Retweet Count:0
#
# Tweet 29:
# Username:cbergan80
# Follower Count:58
# Retweet Count:0
#
# Tweet 30:
# Username:mattutd71
# Follower Count:2635
# Retweet Count:12
#
# Tweet 31:
# Username:IthielBatumike
# Follower Count:803
# Retweet Count:1
#
# Tweet 32:
# Username:themilwaukeemob
# Follower Count:2646
# Retweet Count:0
#
# Tweet 33:
# Username:BeitAleph
# Follower Count:4283
# Retweet Count:116
#
# Tweet 34:
# Username:Hump_45
# Follower Count:1
# Retweet Count:0
#
# Tweet 35:
# Username:JTlitera
# Follower Count:15
# Retweet Count:0
#
# Tweet 36:
# Username:PettyAF11
# Follower Count:10
# Retweet Count:0
#
# Tweet 37:
# Username:5Explorer
# Follower Count:627
# Retweet Count:314
#
# Tweet 38:
# Username:SaimaNiaz8
# Follower Count:33
# Retweet Count:0
#
# Tweet 39:
# Username:CampbellBernel
# Follower Count:30
# Retweet Count:0
#
# Tweet 40:
# Username:PhoenixSquawk
# Follower Count:1441
# Retweet Count:0
#
# Tweet 41:
# Username:sorrowen
# Follower Count:1211
# Retweet Count:0
#
# Tweet 42:
# Username:bibifl59
# Follower Count:3003
# Retweet Count:40
#
# Tweet 43:
# Username:2B_DrDavis
# Follower Count:425
# Retweet Count:2980
#
# Tweet 44:
# Username:danp2078r
# Follower Count:247
# Retweet Count:0
#
# Tweet 45:
# Username:becky34821045
# Follower Count:58
# Retweet Count:434
#
# Tweet 46:
# Username:joebiden_tweets
# Follower Count:3
# Retweet Count:0
#
# Tweet 47:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 48:
# Username:CrazyFUpWorld1
# Follower Count:276
# Retweet Count:0
#
# Tweet 49:
# Username:sapphofem
# Follower Count:3578
# Retweet Count:0
#
# Tweet 50:
# Username:SebastienneL
# Follower Count:3985
# Retweet Count:12
#
# Tweet 51:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 52:
# Username:Shuttlecock7
# Follower Count:138
# Retweet Count:593
#
# Tweet 53:
# Username:SeemaSapraLaw
# Follower Count:804
# Retweet Count:0
#
# Tweet 54:
# Username:RLG_PE
# Follower Count:181
# Retweet Count:0
#
# Tweet 55:
# Username:AFGinBLOOD
# Follower Count:7
# Retweet Count:2
#
# Tweet 56:
# Username:666_nostradamus
# Follower Count:1989
# Retweet Count:6
#
# Tweet 57:
# Username:raisingcontine1
# Follower Count:5
# Retweet Count:0
#
# Tweet 58:
# Username:SinghSumitech
# Follower Count:21
# Retweet Count:0
#
# Tweet 59:
# Username:niknikMoore
# Follower Count:239
# Retweet Count:2
#
# Tweet 60:
# Username:zahirQureshe
# Follower Count:2613
# Retweet Count:2
#
# Tweet 61:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 62:
# Username:DragutinNikoli2
# Follower Count:77
# Retweet Count:1
#
# Tweet 63:
# Username:08Csi
# Follower Count:6254
# Retweet Count:12
#
# Tweet 64:
# Username:HSternIsBatman
# Follower Count:61
# Retweet Count:0
#
# Tweet 65:
# Username:ErDhiruSingh
# Follower Count:824
# Retweet Count:0
#
# Tweet 66:
# Username:iamths1973
# Follower Count:1197
# Retweet Count:0
#
# Tweet 67:
# Username:KhaledAlmaeena
# Follower Count:23046
# Retweet Count:0
#
# Tweet 68:
# Username:RLG_PE
# Follower Count:181
# Retweet Count:0
#
# Tweet 69:
# Username:sai_dir01
# Follower Count:59
# Retweet Count:3
#
# Tweet 70:
# Username:arbin_pajaziti
# Follower Count:0
# Retweet Count:0
#
# Tweet 71:
# Username:BJArmst67789812
# Follower Count:421
# Retweet Count:593
#
# Tweet 72:
# Username:JatinJayKaran3
# Follower Count:208
# Retweet Count:1
#
# Tweet 73:
# Username:Kid_inthe_Crowd
# Follower Count:182
# Retweet Count:0
#
# Tweet 74:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 75:
# Username:Verbramdt
# Follower Count:204
# Retweet Count:0
#
# Tweet 76:
# Username:upbeat_20
# Follower Count:237
# Retweet Count:858
#
# Tweet 77:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 78:
# Username:SweatyYeti5
# Follower Count:0
# Retweet Count:0
#
# Tweet 79:
# Username:SurgingRite
# Follower Count:1447
# Retweet Count:12
#
# Tweet 80:
# Username:gellio_sf
# Follower Count:517
# Retweet Count:0
#
# Tweet 81:
# Username:helena_ambrosio
# Follower Count:301
# Retweet Count:0
#
# Tweet 82:
# Username:cat_joba
# Follower Count:1859
# Retweet Count:2392
#
# Tweet 83:
# Username:AugustinaStudio
# Follower Count:304
# Retweet Count:12
#
# Tweet 84:
# Username:_hammadahmed
# Follower Count:129
# Retweet Count:0
#
# Tweet 85:
# Username:zazadeh0111
# Follower Count:575
# Retweet Count:183
#
# Tweet 86:
# Username:JimboCharlieAsh
# Follower Count:2813
# Retweet Count:0
#
# Tweet 87:
# Username:wardy993
# Follower Count:6
# Retweet Count:0
#
# Tweet 88:
# Username:KimHandley1
# Follower Count:11593
# Retweet Count:141
#
# Tweet 89:
# Username:TheKusher
# Follower Count:148
# Retweet Count:1
#
# Tweet 90:
# Username:LGallegos23
# Follower Count:403
# Retweet Count:0
#
# Tweet 91:
# Username:mariazak18
# Follower Count:696
# Retweet Count:36
#
# Tweet 92:
# Username:mizirregular
# Follower Count:345
# Retweet Count:0
#
# Tweet 93:
# Username:rdsathene
# Follower Count:4122
# Retweet Count:0
#
# Tweet 94:
# Username:DeFrustratedOne
# Follower Count:59
# Retweet Count:88
#
# Tweet 95:
# Username:BenjoJ
# Follower Count:25
# Retweet Count:0
#
# Tweet 96:
# Username:TheKusher
# Follower Count:148
# Retweet Count:1
#
# Tweet 97:
# Username:Tayto02000793
# Follower Count:6
# Retweet Count:0
#
# Tweet 98:
# Username:ufuomaogba
# Follower Count:466
# Retweet Count:4725
#
# Tweet 99:
# Username:ChineduBiafra5
# Follower Count:2040
# Retweet Count:465
#
# Tweet 100:
# Username:ab_peter
# Follower Count:1
# Retweet Count:0
